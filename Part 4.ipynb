# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs 
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df4
# Out:
#      Opening  Opening.1                       Title  \
# 0    OCTOBER          2           Wonder Woman 1984
# 1    OCTOBER         16                    Candyman
# 2    OCTOBER         16  The Trial of the Chicago 7
# 3    OCTOBER         23           Death on the Nile
# 4    OCTOBER         23                   Connected
# 5    OCTOBER         30                      Fatale
# 6    OCTOBER         30                   Come Play
# 7   NOVEMBER          6                 Black Widow
# 8   NOVEMBER          6                  Let Him Go
# 9   NOVEMBER         13    Clifford the Big Red Dog
# 10  NOVEMBER         13                  Deep Water
# 11  NOVEMBER         13          The Comeback Trail
# 12  NOVEMBER         20              No Time to Die
# 13  NOVEMBER         20                        Soul
# 14  NOVEMBER         20                  The Father
# 15  NOVEMBER         25             Happiest Season
# 16  NOVEMBER         25                    Voyagers
# 17  DECEMBER          4               The Empty Man
# 18  DECEMBER         11                    Free Guy
# 19  DECEMBER         18                        Dune
# 20  DECEMBER         18             West Side Story
# 21  DECEMBER         18            Coming 2 America
# 22  DECEMBER         23                The Croods 2
# 23  DECEMBER         25           News of the World
#
#                                    Production company  \
# 0   Warner Bros. Pictures / DC Films / Atlas Enter...
# 1   Universal Pictures / Metro-Goldwyn-Mayer / Mon...
# 2   Netflix / Paramount Pictures / DreamWorks Pict...
# 3       20th Century Studios / Scott Free Productions
# 4         Columbia Pictures / Sony Pictures Animation
# 5                                           Lionsgate
# 6                                      Focus Features
# 7                                      Marvel Studios
# 8                                      Focus Features
# 9   Paramount Pictures / Entertainment One / Walde...
# 10         20th Century Studios / Regency Enterprises
# 11                           Cloudburst Entertainment
# 12  Metro-Goldwyn-Mayer / Universal Pictures / Eon...
# 13     Walt Disney Pictures / Pixar Animation Studios
# 14                             Sony Pictures Classics
# 15               TriStar Pictures / Entertainment One
# 16                                          Lionsgate
# 17                               20th Century Studios
# 18  20th Century Studios / 21 Laps Entertainment /...
# 19    Warner Bros. Pictures / Legendary Entertainment
# 20        20th Century Studios / Amblin Entertainment
# 21                                 Paramount Pictures
# 22          Universal Pictures / DreamWorks Animation
# 23                                 Universal Pictures
#
#                                         Cast and crew   Ref.
# 0   Patty Jenkins (director/screenplay); Geoff Joh...  [128]
# 1   Nia DaCosta (director/screenplay); Jordan Peel...  [129]
# 2   Aaron Sorkin (director/screenplay); Sacha Baro...  [130]
# 3   Kenneth Branagh (director); Michael Green (scr...  [131]
# 4   Mike Rianda (director/screenplay); Jeff Rowe (...  [132]
# 5   Deon Taylor (director); David Loughery (screen...  [133]
# 6   Jacob Chase (director/screenplay); Gillian Jac...  [134]
# 7   Cate Shortland (director); Eric Pearson (scree...  [135]
# 8   Thomas Bezucha (director/screenplay); Kevin Co...  [136]
# 9   Walt Becker (director); Jay Scherick, David Ro...  [137]
# 10  Adrian Lyne (director); Zach Helm, Sam Levinso...  [138]
# 11  George Gallo (director/screenplay); Josh Posne...  [139]
# 12  Cary Joji Fukunaga (director/screenplay); Neal...  [140]
# 13  Pete Docter (director/screenplay); Mike Jones,...  [141]
# 14  Florian Zeller (director/screenplay); Christop...  [142]
# 15  Clea DuVall (director/screenplay); Mary Hollan...  [143]
# 16  Neil Burger (director/screenplay); Colin Farre...  [144]
# 17  David Prior (director/screenplay); James Badge...  [145]
# 18  Shawn Levy (director); Matt Lieberman, Zak Pen...  [146]
# 19  Denis Villeneuve (director/screenplay); Jon Sp...  [147]
# 20  Steven Spielberg (director); Tony Kushner (scr...    [3]
# 21  Craig Brewer (director); Kenya Barris, Barry W...  [148]
# 22  Joel Crawford (director); Kevin Hageman, Dan H...  [149]
# 23  Paul Greengrass (director/screenplay); Luke Da...  [150]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          3         The Grudge
# 1     JANUARY         10         Underwater
# 2     JANUARY         10        Like a Boss
# 3     JANUARY         10  Inherit the Viper
# 4     JANUARY         10         The Sonata
# ..        ...        ...                ...
# 147  DECEMBER         18               Dune
# 148  DECEMBER         18    West Side Story
# 149  DECEMBER         18   Coming 2 America
# 150  DECEMBER         23       The Croods 2
# 151  DECEMBER         25  News of the World
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3       Barry Films / Tycor International Film Company
# 4                                   Screen Media Films
# ..                                                 ...
# 147    Warner Bros. Pictures / Legendary Entertainment
# 148        20th Century Studios / Amblin Entertainment
# 149                                 Paramount Pictures
# 150          Universal Pictures / DreamWorks Animation
# 151                                 Universal Pictures
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# 4    Andrew Desmond (director/screenplay); Arthur M...    [6]
# ..                                                 ...    ...
# 147  Denis Villeneuve (director/screenplay); Jon Sp...  [147]
# 148  Steven Spielberg (director); Tony Kushner (scr...    [3]
# 149  Craig Brewer (director); Kenya Barris, Barry W...  [148]
# 150  Joel Crawford (director); Kevin Hageman, Dan H...  [149]
# 151  Paul Greengrass (director/screenplay); Luke Da...  [150]
#
# [152 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                  Title                                      Cast and crew
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 147               Dune  Denis Villeneuve (director/screenplay); Jon Sp...
# 148    West Side Story  Steven Spielberg (director); Tony Kushner (scr...
# 149   Coming 2 America  Craig Brewer (director); Kenya Barris, Barry W...
# 150       The Croods 2  Joel Crawford (director); Kevin Hageman, Dan H...
# 151  News of the World  Paul Greengrass (director/screenplay); Luke Da...
#
# [152 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'e1a5094fe805d86d66a3e6c3515237db'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df_2020['genres'] = df_2020['Title'].apply(lambda x: get_genre(str(x)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-8d65841816c4> in <module>
# ----> 1 df_2020['genres'] = df_2020['Title'].apply(lambda x: get_genre(str(x)))
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-70-8d65841816c4> in <lambda>(x)
# ----> 1 df_2020['genres'] = df_2020['Title'].apply(lambda x: get_genre(str(x)))
#
# <ipython-input-69-0d0c9142d31b> in get_genre(x)
#       4     genres = []
#       5     result = tmdb_movie.search(x)
# ----> 6     movie_id = result[1].id
#       7     response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
#       8     data_json = response.json()
#
# IndexError: list index out of range

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
